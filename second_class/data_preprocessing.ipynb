# %% [markdown]
# # Data pre-processing
#
# ### Pre-Processing of COVID-19 data in Piauí
#
# Presenting a jupyter notebook generates 4 pickles X_train.pickle, y_train.pickle, X_test.pickle and y_test.pickle referring to pre-processed data considering the dataset of COVID-19 cases in the state of Piauí. Assume that the target (y) of the dataset is the attribute number of deaths;

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

# %% [markdown]
# ## Loading the data

# %%
# selecting in the dataset only the data from piauí by the 'state' column
data = pd.read_csv('caso.csv')
data_piaui = data[data['state'] == 'PI']
data_piaui
# Out:
#                date state         city place_type  confirmed  deaths  \
# 2049353  2022-02-16    PI          NaN      state     360563    7580
# 2049354  2022-02-15    PI          NaN      state     359519    7571
# 2049355  2022-02-14    PI          NaN      state     358516    7558
# 2049356  2022-02-13    PI          NaN      state     357810    7545
# 2049357  2022-02-12    PI          NaN      state     357107    7535
# ...             ...   ...          ...        ...        ...     ...
# 2191916  2020-04-27    PI  Água Branca       city          6       0
# 2191917  2020-04-26    PI  Água Branca       city          4       0
# 2191918  2020-04-25    PI  Água Branca       city          4       0
# 2191919  2020-04-24    PI  Água Branca       city          4       0
# 2191920  2020-04-23    PI  Água Branca       city          3       0
#
#          order_for_place  is_last  estimated_population_2019  \
# 2049353              700     True                  3273227.0
# 2049354              699    False                  3273227.0
# 2049355              698    False                  3273227.0
# 2049356              697    False                  3273227.0
# 2049357              696    False                  3273227.0
# ...                  ...      ...                        ...
# 2191916                5    False                    17411.0
# 2191917                4    False                    17411.0
# 2191918                3    False                    17411.0
# 2191919                2    False                    17411.0
# 2191920                1    False                    17411.0
#
#          estimated_population  city_ibge_code  confirmed_per_100k_inhabitants  \
# 2049353             3281480.0            22.0                     10987.81647
# 2049354             3281480.0            22.0                     10956.00156
# 2049355             3281480.0            22.0                     10925.43608
# 2049356             3281480.0            22.0                     10903.92140
# 2049357             3281480.0            22.0                     10882.49814
# ...                       ...             ...                             ...
# 2191916               17470.0       2200202.0                        34.34459
# 2191917               17470.0       2200202.0                        22.89639
# 2191918               17470.0       2200202.0                        22.89639
# 2191919               17470.0       2200202.0                        22.89639
# 2191920               17470.0       2200202.0                        17.17230
#
#          death_rate
# 2049353      0.0210
# 2049354      0.0211
# 2049355      0.0211
# 2049356      0.0211
# 2049357      0.0211
# ...             ...
# 2191916      0.0000
# 2191917      0.0000
# 2191918      0.0000
# 2191919      0.0000
# 2191920      0.0000
#
# [142568 rows x 13 columns]

# %% [markdown]
# ## Handling missing dataes

# %%
data_piaui.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142568 entries, 2049353 to 2191920
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   date                            142568 non-null  object
#  1   state                           142568 non-null  object
#  2   city                            141868 non-null  object
#  3   place_type                      142568 non-null  object
#  4   confirmed                       142568 non-null  int64
#  5   deaths                          142568 non-null  int64
#  6   order_for_place                 142568 non-null  int64
#  7   is_last                         142568 non-null  bool
#  8   estimated_population_2019       142568 non-null  float64
#  9   estimated_population            142568 non-null  float64
#  10  city_ibge_code                  142568 non-null  float64
#  11  confirmed_per_100k_inhabitants  142349 non-null  float64
#  12  death_rate                      142568 non-null  float64
# dtypes: bool(1), float64(5), int64(3), object(4)
# memory usage: 14.3+ MB

# %%
data_piaui_t = data_piaui.dropna(subset=["city", "confirmed_per_100k_inhabitants"])

# %%
data_piaui_t
# Out:
#                date state         city place_type  confirmed  deaths  \
# 2050053  2022-02-15    PI        Acauã       city        228       2
# 2050054  2022-02-14    PI        Acauã       city        228       2
# 2050055  2022-02-13    PI        Acauã       city        228       2
# 2050056  2022-02-12    PI        Acauã       city        228       2
# 2050057  2022-02-11    PI        Acauã       city        228       2
# ...             ...   ...          ...        ...        ...     ...
# 2191916  2020-04-27    PI  Água Branca       city          6       0
# 2191917  2020-04-26    PI  Água Branca       city          4       0
# 2191918  2020-04-25    PI  Água Branca       city          4       0
# 2191919  2020-04-24    PI  Água Branca       city          4       0
# 2191920  2020-04-23    PI  Água Branca       city          3       0
#
#          order_for_place  is_last  estimated_population_2019  \
# 2050053              619     True                     7084.0
# 2050054              618    False                     7084.0
# 2050055              617    False                     7084.0
# 2050056              616    False                     7084.0
# 2050057              615    False                     7084.0
# ...                  ...      ...                        ...
# 2191916                5    False                    17411.0
# 2191917                4    False                    17411.0
# 2191918                3    False                    17411.0
# 2191919                2    False                    17411.0
# 2191920                1    False                    17411.0
#
#          estimated_population  city_ibge_code  confirmed_per_100k_inhabitants  \
# 2050053                7102.0       2200053.0                      3210.36328
# 2050054                7102.0       2200053.0                      3210.36328
# 2050055                7102.0       2200053.0                      3210.36328
# 2050056                7102.0       2200053.0                      3210.36328
# 2050057                7102.0       2200053.0                      3210.36328
# ...                       ...             ...                             ...
# 2191916               17470.0       2200202.0                        34.34459
# 2191917               17470.0       2200202.0                        22.89639
# 2191918               17470.0       2200202.0                        22.89639
# 2191919               17470.0       2200202.0                        22.89639
# 2191920               17470.0       2200202.0                        17.17230
#
#          death_rate
# 2050053      0.0088
# 2050054      0.0088
# 2050055      0.0088
# 2050056      0.0088
# 2050057      0.0088
# ...             ...
# 2191916      0.0000
# 2191917      0.0000
# 2191918      0.0000
# 2191919      0.0000
# 2191920      0.0000
#
# [141649 rows x 13 columns]

# %%
# Reset the indexes
data_piaui_t = data_piaui_t.reset_index(drop=True)
data_piaui_t
# Out:
#               date state         city place_type  confirmed  deaths  \
# 0       2022-02-15    PI        Acauã       city        228       2
# 1       2022-02-14    PI        Acauã       city        228       2
# 2       2022-02-13    PI        Acauã       city        228       2
# 3       2022-02-12    PI        Acauã       city        228       2
# 4       2022-02-11    PI        Acauã       city        228       2
# ...            ...   ...          ...        ...        ...     ...
# 141644  2020-04-27    PI  Água Branca       city          6       0
# 141645  2020-04-26    PI  Água Branca       city          4       0
# 141646  2020-04-25    PI  Água Branca       city          4       0
# 141647  2020-04-24    PI  Água Branca       city          4       0
# 141648  2020-04-23    PI  Água Branca       city          3       0
#
#         order_for_place  is_last  estimated_population_2019  \
# 0                   619     True                     7084.0
# 1                   618    False                     7084.0
# 2                   617    False                     7084.0
# 3                   616    False                     7084.0
# 4                   615    False                     7084.0
# ...                 ...      ...                        ...
# 141644                5    False                    17411.0
# 141645                4    False                    17411.0
# 141646                3    False                    17411.0
# 141647                2    False                    17411.0
# 141648                1    False                    17411.0
#
#         estimated_population  city_ibge_code  confirmed_per_100k_inhabitants  \
# 0                     7102.0       2200053.0                      3210.36328
# 1                     7102.0       2200053.0                      3210.36328
# 2                     7102.0       2200053.0                      3210.36328
# 3                     7102.0       2200053.0                      3210.36328
# 4                     7102.0       2200053.0                      3210.36328
# ...                      ...             ...                             ...
# 141644               17470.0       2200202.0                        34.34459
# 141645               17470.0       2200202.0                        22.89639
# 141646               17470.0       2200202.0                        22.89639
# 141647               17470.0       2200202.0                        22.89639
# 141648               17470.0       2200202.0                        17.17230
#
#         death_rate
# 0           0.0088
# 1           0.0088
# 2           0.0088
# 3           0.0088
# 4           0.0088
# ...            ...
# 141644      0.0000
# 141645      0.0000
# 141646      0.0000
# 141647      0.0000
# 141648      0.0000
#
# [141649 rows x 13 columns]

# %%
data_piaui_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141649 entries, 0 to 141648
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   date                            141649 non-null  object
#  1   state                           141649 non-null  object
#  2   city                            141649 non-null  object
#  3   place_type                      141649 non-null  object
#  4   confirmed                       141649 non-null  int64
#  5   deaths                          141649 non-null  int64
#  6   order_for_place                 141649 non-null  int64
#  7   is_last                         141649 non-null  bool
#  8   estimated_population_2019       141649 non-null  float64
#  9   estimated_population            141649 non-null  float64
#  10  city_ibge_code                  141649 non-null  float64
#  11  confirmed_per_100k_inhabitants  141649 non-null  float64
#  12  death_rate                      141649 non-null  float64
# dtypes: bool(1), float64(5), int64(3), object(4)
# memory usage: 13.1+ MB

# %%
# Separating the target (y) from the dataset is the attribute number of deaths
data_piaui_alvo = data_piaui_t["deaths"].copy()
data_piaui_t = data_piaui_t.drop('deaths', axis=1) 
data_piaui_alvo
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 141644    0
# 141645    0
# 141646    0
# 141647    0
# 141648    0
# Name: deaths, Length: 141649, dtype: int64

# %% [markdown]
# ## Handling categorical data

# %%
from sklearn.preprocessing import LabelEncoder
data_piaui_categoria = data_piaui_t['is_last']
data_piaui_categoria1 = data_piaui_t['city']
le = LabelEncoder()
data_piaui_categoria_le = le.fit_transform(data_piaui_categoria)
data_piaui_categoria_le1 = le.fit_transform(data_piaui_categoria1)

# %%
# Transforming data into dataFrame
is_last = pd.DataFrame(data_piaui_categoria_le, columns=['is_last'])
city = pd.DataFrame(data_piaui_categoria_le1, columns=['city'])

# %%
city.head()
# Out:
#    city
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
is_last.head()
# Out:
#    is_last
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Drop in the is_last column
data_piaui_t = data_piaui_t.drop(['is_last', 'city'], axis=1)
data_piaui_t
# Out:
#               date state place_type  confirmed  order_for_place  \
# 0       2022-02-15    PI       city        228              619
# 1       2022-02-14    PI       city        228              618
# 2       2022-02-13    PI       city        228              617
# 3       2022-02-12    PI       city        228              616
# 4       2022-02-11    PI       city        228              615
# ...            ...   ...        ...        ...              ...
# 141644  2020-04-27    PI       city          6                5
# 141645  2020-04-26    PI       city          4                4
# 141646  2020-04-25    PI       city          4                3
# 141647  2020-04-24    PI       city          4                2
# 141648  2020-04-23    PI       city          3                1
#
#         estimated_population_2019  estimated_population  city_ibge_code  \
# 0                          7084.0                7102.0       2200053.0
# 1                          7084.0                7102.0       2200053.0
# 2                          7084.0                7102.0       2200053.0
# 3                          7084.0                7102.0       2200053.0
# 4                          7084.0                7102.0       2200053.0
# ...                           ...                   ...             ...
# 141644                    17411.0               17470.0       2200202.0
# 141645                    17411.0               17470.0       2200202.0
# 141646                    17411.0               17470.0       2200202.0
# 141647                    17411.0               17470.0       2200202.0
# 141648                    17411.0               17470.0       2200202.0
#
#         confirmed_per_100k_inhabitants  death_rate
# 0                           3210.36328      0.0088
# 1                           3210.36328      0.0088
# 2                           3210.36328      0.0088
# 3                           3210.36328      0.0088
# 4                           3210.36328      0.0088
# ...                                ...         ...
# 141644                        34.34459      0.0000
# 141645                        22.89639      0.0000
# 141646                        22.89639      0.0000
# 141647                        22.89639      0.0000
# 141648                        17.17230      0.0000
#
# [141649 rows x 10 columns]

# %%
# concatenate
data_piuai_encoded = pd.concat([data_piaui_t, is_last, city], axis=1)
data_piuai_encoded
# Out:
#               date state place_type  confirmed  order_for_place  \
# 0       2022-02-15    PI       city        228              619
# 1       2022-02-14    PI       city        228              618
# 2       2022-02-13    PI       city        228              617
# 3       2022-02-12    PI       city        228              616
# 4       2022-02-11    PI       city        228              615
# ...            ...   ...        ...        ...              ...
# 141644  2020-04-27    PI       city          6                5
# 141645  2020-04-26    PI       city          4                4
# 141646  2020-04-25    PI       city          4                3
# 141647  2020-04-24    PI       city          4                2
# 141648  2020-04-23    PI       city          3                1
#
#         estimated_population_2019  estimated_population  city_ibge_code  \
# 0                          7084.0                7102.0       2200053.0
# 1                          7084.0                7102.0       2200053.0
# 2                          7084.0                7102.0       2200053.0
# 3                          7084.0                7102.0       2200053.0
# 4                          7084.0                7102.0       2200053.0
# ...                           ...                   ...             ...
# 141644                    17411.0               17470.0       2200202.0
# 141645                    17411.0               17470.0       2200202.0
# 141646                    17411.0               17470.0       2200202.0
# 141647                    17411.0               17470.0       2200202.0
# 141648                    17411.0               17470.0       2200202.0
#
#         confirmed_per_100k_inhabitants  death_rate  is_last  city
# 0                           3210.36328      0.0088        1     0
# 1                           3210.36328      0.0088        0     0
# 2                           3210.36328      0.0088        0     0
# 3                           3210.36328      0.0088        0     0
# 4                           3210.36328      0.0088        0     0
# ...                                ...         ...      ...   ...
# 141644                        34.34459      0.0000        0   223
# 141645                        22.89639      0.0000        0   223
# 141646                        22.89639      0.0000        0   223
# 141647                        22.89639      0.0000        0   223
# 141648                        17.17230      0.0000        0   223
#
# [141649 rows x 12 columns]

# %%
# removing 'unnecessary' fields
data_piuai_encoded = data_piuai_encoded.drop(['date', 'state', 'place_type', 'city_ibge_code'], axis=1)

# %%
data_piuai_encoded.head()
# Out:
#    confirmed  order_for_place  estimated_population_2019  \
# 0        228              619                     7084.0
# 1        228              618                     7084.0
# 2        228              617                     7084.0
# 3        228              616                     7084.0
# 4        228              615                     7084.0
#
#    estimated_population  confirmed_per_100k_inhabitants  death_rate  is_last  \
# 0                7102.0                      3210.36328      0.0088        1
# 1                7102.0                      3210.36328      0.0088        0
# 2                7102.0                      3210.36328      0.0088        0
# 3                7102.0                      3210.36328      0.0088        0
# 4                7102.0                      3210.36328      0.0088        0
#
#    city
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
data_piuai_encoded.to_csv('data_piaui.csv', index=False)

# %% [markdown]
# ## Splitting data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(data_piuai_encoded, data_piaui_alvo, test_size = 0.2, random_state=1, shuffle=True)

# %%
print(X_train)
# Out:
#         confirmed  order_for_place  estimated_population_2019  \
# 50911          97              289                     2558.0
# 78026         137              274                     6441.0
# 21449         133              129                     8329.0
# 117126        643              324                    12711.0
# 76385           1               17                     5349.0
# ...           ...              ...                        ...
# 73349        1152              439                     5295.0
# 109259         64              140                     6432.0
# 50057         186              531                     4463.0
# 5192          892              554                     6788.0
# 128037        268              117                     7989.0
#
#         estimated_population  confirmed_per_100k_inhabitants  death_rate  \
# 50911                 2560.0                      3789.06250      0.0412
# 78026                 6449.0                      2124.36037      0.0000
# 21449                 8347.0                      1593.38685      0.0075
# 117126               12746.0                      5044.71991      0.0124
# 76385                 5351.0                        18.68810      0.0000
# ...                      ...                             ...         ...
# 73349                 5283.0                     21805.79216      0.0139
# 109259                6433.0                       994.87020      0.0156
# 50057                 4462.0                      4168.53429      0.0269
# 5192                  6783.0                     13150.52337      0.0135
# 128037                8038.0                      3334.16273      0.0037
#
#         is_last  city
# 50911         0    80
# 78026         0   123
# 21449         0    33
# 117126        0   185
# 76385         0   120
# ...         ...   ...
# 73349         0   116
# 109259        0   172
# 50057         0    79
# 5192          0     8
# 128037        0   202
#
# [113319 rows x 8 columns]

# %% [markdown]
# ## Feature Scaling

# %%
#z = (x - u) / s
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[-0.1510606  -0.16062652 -0.20670927 ...  0.18862142 -0.04054729
#   -0.48962709]
#  [-0.14372219 -0.24228777 -0.14313121 ... -0.44246783 -0.04054729
#    0.17512196]
#  [-0.14445603 -1.03167983 -0.11221815 ... -0.32758508 -0.04054729
#   -1.21621327]
#  ...
#  [-0.13473262  1.15684162 -0.17551787 ... -0.03042169 -0.04054729
#   -0.50508637]
#  [-0.00520953  1.28205553 -0.13744962 ... -0.23567887 -0.04054729
#   -1.60269528]
#  [-0.11968886 -1.09700883 -0.11778512 ... -0.38579234 -0.04054729
#    1.3964051 ]]

# %%
pickle.dump(X_train, open('X_train.pickle', 'wb'))
pickle.dump(X_test, open('X_test.pickle', 'wb'))
pickle.dump(y_train, open('y_train.pickle', 'wb'))
pickle.dump(y_test, open('y_test.pickle', 'wb'))

# %%
len(X_train)
# Out:
# 113319
